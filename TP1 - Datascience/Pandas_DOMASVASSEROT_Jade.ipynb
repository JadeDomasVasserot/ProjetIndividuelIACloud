# %% [markdown]
# # Pandas : Niveau avancé

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://www.smartdataforlead.com/wp-content/uploads/2018/04/37436658_m.jpg" />

# %% [markdown]
# Approfondissons nos compétences en matière de manipulation de données réelles à partir de la bibliothèque [Pandas](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
#
# Dans ce défi, nous explorerons les informations présentes dans une base de données clients.
#
#
#
# > **Notre objectif est de visualiser la répartition de nos données.**
#
#
#
# **Q1**. Créez une variable `path` puis collez le chemin du jeu de données [suivant](https://raw.githubusercontent.com/Quera-fr/Python-Programming/refs/heads/main/data.csv).

# %%
path = 'https://raw.githubusercontent.com/Quera-fr/Python-Programming/refs/heads/main/data.csv'

# %% [markdown]
# ---
#
# **Q2**. Importez la bibliothèque `pandas` qui sera utilisée tout au long dae ce projet.

# %%
# Importez pandas avec l'alias pd
import pandas as pd

# %% [markdown]
# ---
#
# ## 1. Exploration du jeu de données
#
# Dans cette partie notre objectifs est d'explorer le jeu de données contenant les informations clients.
#
# <img src='https://img.freepik.com/free-vector/business-documents-scanning-electronic-online-doc-with-pie-chart-infographics-data-analytics-annual-report-result-checking-man-with-magnifying-glass-concept-illustration_335657-1770.jpg?w=2000'>
#
# Voici la liste des modules de la bibliotèque pandas qui seront utilisés dans cette partie.
#
# - `.read_csv('chemin du fichier')` : Pour importer un jeu de données à partir de son 'nom de fichier',
# - `.head(n)` : Pour afficher les n premières lignes du le jeu de données,
#
# - `.columns` : Pour afficher la liste des variables.
#
# - `.shape` : Pour afficher les dimensions du jeu de données (nombre de lignes et nombre de colonnes),
# - `.isna().sum()` : Pour afficher le nombre de valeurs manquantes par colonnes
#
#
# - `.info()` : Pour afficher les informations du jeu de données,
# - `.describe()` : Pour afficher les données statistiques du jeu de données.
#
#
# ---
#
#
# **Q3**. Importez votre le jeux de données client dans une variable nomée df. Affichez ensuite les 10 premières lignes de ce jeu de données.

# %%
# Importez le jeu de données dans une variable df

# Affichez la variable df
df = pd.read_csv(path)
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %% [markdown]
# ---
#  **Q4.** Affichez la liste des colonnes du jeu de données.

# %%
#Affichez la liste des colonnes du jeu de données df
df.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1',
#        'Segmentation'],
#       dtype='object')

# %% [markdown]
# ---
# **Q5**. Affichez les dimensions du jeu de données ainsi que le nombre de valeurs manquantes.

# %%
# TODO - Affichez les dimensions
df.shape
# Out:
# (8068, 11)

# %%
# TODO - Affichez le nombre de valeurs manquantes
df.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %% [markdown]
# ---
# **Q6**. Notez vos premières observations sur l'ensembles des données affichées,
# - que contient le jeu de données, quelles sont les variables,
# - quelles sont les dimensions,
# - quelles sont les variables qui contiennent le plus de données manquantes

# %% [markdown]
# Le jeu de données contient 8068 lignes, 11 colonnes : La variable qui contient le plus de données manquantes est la variable `Work_Experience`
#  avec 829 données manquantes.

# %% [markdown]
# [Zone de texte]

# %% [markdown]
# ---
# **Q7**. Affichez les informations puis les données statistics du jeu de données.

# %%
# TODO - Affichez les informations du jeu de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
# TODO - Affichez les statistiques du jeu de données
df.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    8068.000000  8068.000000      7239.000000  7733.000000
# mean   463479.214551    43.466906         2.641663     2.850123
# std      2595.381232    16.711696         3.406763     1.531413
# min    458982.000000    18.000000         0.000000     1.000000
# 25%    461240.750000    30.000000         0.000000     2.000000
# 50%    463472.500000    40.000000         1.000000     3.000000
# 75%    465744.250000    53.000000         4.000000     4.000000
# max    467974.000000    89.000000        14.000000     9.000000

# %% [markdown]
# ---
# **Q8**. À l'aide d'un filtre, créez un sous-échantillon du jeu de données permettant d'afficher les individus : hommes, mariés, de plus de 30 ans de profession ingénieur, affichez ensuite la moyenne des âges de ces individus.

# %%
# Filtre

df[(df.Gender == "Male") & (df.Age > 30) & (df.Ever_Married == 'Yes') & (df.Profession == 'Engineer')]
# Out:
#           ID Gender Ever_Married  Age Graduated Profession  Work_Experience  \
# 44    466152   Male          Yes   40        No   Engineer              8.0
# 78    461558   Male          Yes   45       Yes   Engineer              2.0
# 320   462541   Male          Yes   70       Yes   Engineer              4.0
# 381   461494   Male          Yes   33        No   Engineer              0.0
# 415   460941   Male          Yes   72        No   Engineer              1.0
# ...      ...    ...          ...  ...       ...        ...              ...
# 7574  467470   Male          Yes   53       Yes   Engineer              1.0
# 7625  464531   Male          Yes   38        No   Engineer              0.0
# 7850  459369   Male          Yes   35        No   Engineer              NaN
# 7883  465440   Male          Yes   62        No   Engineer              1.0
# 7953  462194   Male          Yes   61        No   Engineer              0.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# ...

# %%
# Groupement de données
df.groupby(['Profession'])[["Age", "Work_Experience"]].mean()
# Out:
#                      Age  Work_Experience
# Profession
# Artist         46.327504         2.708460
# Doctor         37.225291         2.622222
# Engineer       41.745351         2.595541
# Entertainment  43.005269         2.755220
# Executive      51.096828         2.327652
# Healthcare     26.827327         2.592061
# Homemaker      37.922764         6.464455
# Lawyer         75.215088         1.229630
# Marketing      36.818493         2.616601

# %%
# Groupement de données df.groupby(['Gender', 'Profession'])['Work_Experience', 'Age'].mean()
df.groupby(['Gender', 'Profession'])[["Age", "Work_Experience"]].mean()
# Out:
#                             Age  Work_Experience
# Gender Profession
# Female Artist         46.406430         2.817446
#        Doctor         37.815789         2.387097
#        Engineer       41.509839         2.650794
#        Entertainment  39.818182         3.276596
#        Executive      43.593750         2.423077
#        Healthcare     27.475763         2.766000
#        Homemaker      37.113300         6.560000
#        Lawyer         74.905537         1.247232
#        Marketing      36.201220         3.271429
# Male   Artist         46.254029         2.606873
#        Doctor         36.757812         2.809117
#        Engineer       42.685714         2.370968
#        Entertainment  44.163793         2.559809
#        Executive      51.520282         2.322709
#        Healthcare     26.361290         2.464912
#        Homemaker      41.744186         6.000000
#        Lawyer         75.515823         1.211896
#        Marketing      37.609375         1.805310

# %%
# Concatenation dataframe

# %% [markdown]
# ---
# **Q9**. Notez vos observtions dans la zone de texte ci-dessous :
# - Quelles sont les variables qualitatives ?
# - Quelles sont les variables quantitatives ?
# - Quel est le poids du jeu de données ?
# - Que pouvez-vous dire sur l'âge des clients ?
# - Que pouvez-vous dire sur la taille des familles ?
# - Que pouvez-vous dire sur le nombre d'exprience professionelle ?

# %% [markdown]
# [Zone de texte]

# %% [markdown]
# # 2. Data Visualisation
#
# A l'aide du site suivant : https://www.python-graph-gallery.com et de la bibliothèque `seaborn`, nous allons afficher quelques graphiques.
#
# * Import de la bibliothèque : `import seaborn as sns`
#
# - Un histograme : https://www.python-graph-gallery.com/histogram/
#
#       `sns.histplot(data)`
#
# - Une boite à moustache : https://www.python-graph-gallery.com/boxplot/
#       `sns.boxplot(data)`
#
# - Un digramme circulaire : https://www.python-graph-gallery.com/pie-plot/
#         `import matplotlib.pyplot as plt`
#         `plt.pie(data)`

# %%
# Histogramme des ages : sns.histplot
import seaborn as sns

sns.histplot(df.Age, bins=71)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.Age.max() -df.Age.min()
# Out:
# 71

# %%
# Histogramme des professions
sns.boxplot(x=df.Age)
# Out:
# <Axes: xlabel='Age'>

# %%
# Boîte à moustache de la variable "Age"


sns.boxplot(x=df.Age, hue=df.Gender, y=df.Profession)
# Out:
# <Axes: xlabel='Age', ylabel='Profession'>

# %%
# Nuage de point des âges en fonction du nombre d'année d'expérience : sns.scatterplot
sns.scatterplot(x=df.Age, y=df.Work_Experience, hue=df.Ever_Married)
# Out:
# <Axes: xlabel='Age', ylabel='Work_Experience'>

# %%
# Diagramme circulaire des professions
# Configuration de la palette de couleurs avec Seaborn
colors = sns.color_palette("pastel", len(df))
import matplotlib.pyplot as plt
print(df["Profession"].value_counts())
# Création du diagramme circulaire
plt.pie(
    x=df["Profession"].value_counts(),
    labels=df["Profession"].value_counts().index,
    colors=colors,
    autopct="%.1f%%",  # Affiche les pourcentages
    startangle=90,     # Angle de départ
    wedgeprops={"edgecolor": "black"}  # Bordures des parts
)

# Titre du graphique
plt.title("Répartition des professions")
plt.show()
# Out:
# Profession
# Artist           2516
# Healthcare       1332
# Entertainment     949
# Engineer          699
# Doctor            688
# Lawyer            623
# Executive         599
# Marketing         292
# Homemaker         246
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Nettoyage du jeu de données
#
# Dans cette partie nous allons traiter les données présentes dans notre dataframe en remplaçant les données qualitative par des données quantitatives.
#
# <img src='https://miro.medium.com/max/1000/1*ZtO60QvYVzN3rU0VuSSU1g.jpeg'>
#
#
# Ce traitement de donné nous permetra d'utiliser par la suite nos algoritmes de segmentation et de clustering.
#
#
#
#
#
# Voici la liste des modules de pandas qui seront utilisés dans cette partie :
# - `df.dropna()` : Pour supprimer les lignes contenant des valeurs manquantes dans un jeu de données df. Pour concerver les modifications il faudra réassigner la variable df ==> df = df.dropna()
#
# - `.drop_duplicates()` : Pour supprimer les lignes dupliquées.
#
#
# - `df.drop(['nom de la colone'], axis=1)` : Pour supprimer une colonne du jeu de données df. Pour concerver les modifications il faudra réassigner la variable df.
#
#
# - `df['nom de la colone'].value_counts()` : Pour afficher la répartion des valeurs de la varialbe mentionnée entre crochet.
#
# - `df.reset_index()` : Réinitialisez l'indexation du jeu de données
#
#
# - `categorical(df, 'nom de la colone')` : Fonction permettant de remplacer les valeurs qualitatives par des valeurs quantitatives. Pour concerver les modifications il faudra réassigner la variable df ==> df = catégorical(df, 'nom de la colone').
#
#
# - `df.to_csv('fichier.csv')` : Pour sauvegarder votre jeu de données.

# %%
#TODO -  Supprimez les données dupliquées
df.drop_duplicates(inplace=True)
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
# Remplacer les données manquantes par la mediane : .fillna() (facultatif)
df["Work_Experience"] = df["Work_Experience"].fillna(df["Work_Experience"].median())
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
#TODO -  Supprimez les données manquantes
df.dropna(inplace=True)
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8062  463002    Male          Yes   41       Yes         Artist
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %% [markdown]
# [Zone de texte]

# %% [markdown]
# ---
# **Q10**. Supprimez la colonne 'Var_1' ainsi que la colonne 'ID' du jeu de données.

# %%
# Suppression de la variable ID et Var_1
df.drop(columns=["ID", "Var_1"], inplace=True)
df
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0       Male           No   22        No     Healthcare              1.0
# 1     Female          Yes   38       Yes       Engineer              1.0
# 2     Female          Yes   67       Yes       Engineer              1.0
# 3       Male          Yes   67       Yes         Lawyer              0.0
# 4     Female          Yes   40       Yes  Entertainment              1.0
# ...      ...          ...  ...       ...            ...              ...
# 8062    Male          Yes   41       Yes         Artist              0.0
# 8064    Male           No   35        No      Executive              3.0
# 8065  Female           No   33       Yes     Healthcare              1.0
# 8066  Female           No   27       Yes     Healthcare              1.0
# 8067    Male          Yes   37       Yes      Executive              0.0
#
#      Spending_Score  Family_Size Segmentation
# ...

# %%
# Réinitialisez l'indexation du jeu de données
df.reset_index(drop=True, inplace=True)
df
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0       Male           No   22        No     Healthcare              1.0
# 1     Female          Yes   38       Yes       Engineer              1.0
# 2     Female          Yes   67       Yes       Engineer              1.0
# 3       Male          Yes   67       Yes         Lawyer              0.0
# 4     Female          Yes   40       Yes  Entertainment              1.0
# ...      ...          ...  ...       ...            ...              ...
# 7371    Male          Yes   41       Yes         Artist              0.0
# 7372    Male           No   35        No      Executive              3.0
# 7373  Female           No   33       Yes     Healthcare              1.0
# 7374  Female           No   27       Yes     Healthcare              1.0
# 7375    Male          Yes   37       Yes      Executive              0.0
#
#      Spending_Score  Family_Size Segmentation
# ...

# %%
# Supression d'une ligne (facultatif)
df.drop(index=0, inplace=True)
df
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 1     Female          Yes   38       Yes       Engineer              1.0
# 2     Female          Yes   67       Yes       Engineer              1.0
# 3       Male          Yes   67       Yes         Lawyer              0.0
# 4     Female          Yes   40       Yes  Entertainment              1.0
# 5       Male          Yes   56        No         Artist              0.0
# ...      ...          ...  ...       ...            ...              ...
# 7371    Male          Yes   41       Yes         Artist              0.0
# 7372    Male           No   35        No      Executive              3.0
# 7373  Female           No   33       Yes     Healthcare              1.0
# 7374  Female           No   27       Yes     Healthcare              1.0
# 7375    Male          Yes   37       Yes      Executive              0.0
#
#      Spending_Score  Family_Size Segmentation
# ...

# %%
# Change Type of data : .astype(str) (facultatif)
df.Family_Size.astype(float)
# Out:
# 1       3.0
# 2       1.0
# 3       2.0
# 4       6.0
# 5       2.0
#        ...
# 7371    5.0
# 7372    4.0
# 7373    1.0
# 7374    4.0
# 7375    3.0
# Name: Family_Size, Length: 7375, dtype: float64

# %% [markdown]
# ---
# **Q11**. Traitement de la colonne `Gender`
#
# - Affichez la répartition des valeurs de la colonne `Gender`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Gender`,

# %%
# Affichez la répartition de la colonne 'Gender'
df['Gender'].value_counts().plot(kind='bar', color=colors)
plt.title('Répartition de la colonne Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Afficher la répartition des valeurs dans la colonne 'Gender'
gender_distribution = df['Gender'].value_counts()
gender_distribution
# Out:
# Gender
# Male      4077
# Female    3298
# Name: count, dtype: int64

# %%
# Liste des items d'une colonne
# Liste des éléments uniques dans la colonne 'Gender'
unique_items = df['Gender']

print(unique_items)
# Out:
# 1       Female
# 2       Female
# 3         Male
# 4       Female
# 5         Male
#          ...
# 7371      Male
# 7372      Male
# 7373    Female
# 7374    Female
# 7375      Male
# Name: Gender, Length: 7375, dtype: object

# %%
# Nombre d'itème unique d'une colonne
unique_items = df['Gender'].unique()
unique_items
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ---
# ***Q12***. Transformez les données qualitatives en données quantitatives.

# %%
# Label encoder :from sklearn.preprocessing import LabelEncoder

#pd.get_dummies(df, columns=['Profession'])

# %%
# One Hot Encoding : get_dummies(prefix)

#df = pd.get_dummies(df, columns=['Profession', 'Spending_Score', 'Segmentation'])

# %% [markdown]
# ---
# **Q13**. Traitement de la colonne `Ever_Married`
#
# - Affichez la répartition des valeurs de la colonne `Ever_Married`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Ever_Married`,

# %%
# Affichez la répartition de la colonne 'Ever_Married'
df['Ever_Married'].value_counts().plot(kind='bar', color=colors)
print(df['Ever_Married'].value_counts())
# Out:
# Ever_Married
# Yes    4370
# No     3005
# Name: count, dtype: int64

# %% [markdown]
# [Zone de texte]

# %%
# Remplacez les valeurs qualitatives par des valeurs quantitatives 'Ever_Married'
df['Ever_Married'] = df['Ever_Married'].map({"Yes": 1, "No": 0})
df
# Out:
#       Gender  Ever_Married  Age Graduated     Profession  Work_Experience  \
# 1     Female             1   38       Yes       Engineer              1.0
# 2     Female             1   67       Yes       Engineer              1.0
# 3       Male             1   67       Yes         Lawyer              0.0
# 4     Female             1   40       Yes  Entertainment              1.0
# 5       Male             1   56        No         Artist              0.0
# ...      ...           ...  ...       ...            ...              ...
# 7371    Male             1   41       Yes         Artist              0.0
# 7372    Male             0   35        No      Executive              3.0
# 7373  Female             0   33       Yes     Healthcare              1.0
# 7374  Female             0   27       Yes     Healthcare              1.0
# 7375    Male             1   37       Yes      Executive              0.0
#
#      Spending_Score  Family_Size Segmentation
# ...

# %% [markdown]
# ---
# **Q14**. Traitement de la colonne `Graduated`
#
# - Affichez la répartition des valeurs de la colonne `Graduated`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Graduated`,

# %%
# Affichez la répartition de la colonne 'Graduated'
df['Graduated'].value_counts().plot(kind='bar', color=colors)
print(df['Graduated'].value_counts())
# Out:
# Graduated
# Yes    4648
# No     2727
# Name: count, dtype: int64

# %% [markdown]
# [Zone de texte]

# %%
# Remplacez les valeurs qualitatives par des valeurs quantitatives
df['Graduated'] = df['Graduated'].map({"Yes": 1, "No": 0})
df
# Out:
#       Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 1     Female             1   38          1       Engineer              1.0
# 2     Female             1   67          1       Engineer              1.0
# 3       Male             1   67          1         Lawyer              0.0
# 4     Female             1   40          1  Entertainment              1.0
# 5       Male             1   56          0         Artist              0.0
# ...      ...           ...  ...        ...            ...              ...
# 7371    Male             1   41          1         Artist              0.0
# 7372    Male             0   35          0      Executive              3.0
# 7373  Female             0   33          1     Healthcare              1.0
# 7374  Female             0   27          1     Healthcare              1.0
# 7375    Male             1   37          1      Executive              0.0
#
#      Spending_Score  Family_Size Segmentation
# ...

# %% [markdown]
# ---
# **Q15**. Traitement de la colonne `Profession`
#
# - Affichez la répartition des valeurs de la colonne `Profession`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Profession`,

# %%
#Affichez la répartition de la colonne 'Profession'
df['Profession'].value_counts().plot(kind='bar', color=colors)
print(df['Profession'].value_counts())
# Out:
# Profession
# Artist           2385
# Healthcare       1207
# Entertainment     881
# Engineer          649
# Doctor            646
# Lawyer            571
# Executive         566
# Marketing         263
# Homemaker         207
# Name: count, dtype: int64

# %% [markdown]
# [Zone de texte]

# %%
# Remplacez les valeurs qualitatives par des valeurs quantitatives
df['Profession'] = df['Profession'].map({"Artist": 0, "Healthcare": 1, "Entertainment": 2, "Engineer": 3, "Doctor": 4, "Lawyer": 5, "Executive": 6, "Marketing": 7, "Homemaker": 8})

# %%
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 1     Female             1   38          1           3              1.0
# 2     Female             1   67          1           3              1.0
# 3       Male             1   67          1           5              0.0
# 4     Female             1   40          1           2              1.0
# 5       Male             1   56          0           0              0.0
# ...      ...           ...  ...        ...         ...              ...
# 7371    Male             1   41          1           0              0.0
# 7372    Male             0   35          0           6              3.0
# 7373  Female             0   33          1           1              1.0
# 7374  Female             0   27          1           1              1.0
# 7375    Male             1   37          1           6              0.0
#
#      Spending_Score  Family_Size Segmentation
# 1           Average          3.0            A
# ...

# %% [markdown]
# ---
# **Q16**. Traitement de la colonne `Spending_Score`
#
# - Affichez la répartition des valeurs de la colonne `Spending_Score`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Spending_Score`,

# %%
# Affichez la répartition de la colonne 'Spending_Score'
df['Spending_Score'].value_counts().plot(kind='bar', color=colors)
print(df['Spending_Score'].value_counts())
# Out:
# Spending_Score
# Low        4400
# Average    1844
# High       1131
# Name: count, dtype: int64

# %%
# Remplacez les valeurs qualitatives par des valeurs quantitatives
df['Spending_Score'] = df['Spending_Score'].map({"Low": 0, "Average": 1, "High": 2})

# %%
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 1     Female             1   38          1           3              1.0
# 2     Female             1   67          1           3              1.0
# 3       Male             1   67          1           5              0.0
# 4     Female             1   40          1           2              1.0
# 5       Male             1   56          0           0              0.0
# ...      ...           ...  ...        ...         ...              ...
# 7371    Male             1   41          1           0              0.0
# 7372    Male             0   35          0           6              3.0
# 7373  Female             0   33          1           1              1.0
# 7374  Female             0   27          1           1              1.0
# 7375    Male             1   37          1           6              0.0
#
#       Spending_Score  Family_Size Segmentation
# 1                  1          3.0            A
# ...

# %% [markdown]
# ---
# **Q17**. Traitement de la colonne `Segmentation`
#
# - Affichez la répartition des valeurs de la colonne `Segmentation`,
# - Notez vos observations dans la zonne de texte,
# - Appliquez la fonction `catégorial` à la colonne `Segmentation`,

# %%
#TODO - Affichez la répartition de la colonne 'Segmentation'
df['Segmentation'].value_counts().plot(kind='bar', color=colors)
print(df['Segmentation'].value_counts())
# Out:
# Segmentation
# D    1989
# C    1860
# A    1787
# B    1739
# Name: count, dtype: int64

# %% [markdown]
# [Zone de texte]

# %%
# Remplacez les valeurs qualitatives par des valeurs quantitatives
df["Segmentation"] = df["Segmentation"].map({"A": 0, "B": 1, "C": 2, "D": 3})

# %%
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 1     Female             1   38          1           3              1.0
# 2     Female             1   67          1           3              1.0
# 3       Male             1   67          1           5              0.0
# 4     Female             1   40          1           2              1.0
# 5       Male             1   56          0           0              0.0
# ...      ...           ...  ...        ...         ...              ...
# 7371    Male             1   41          1           0              0.0
# 7372    Male             0   35          0           6              3.0
# 7373  Female             0   33          1           1              1.0
# 7374  Female             0   27          1           1              1.0
# 7375    Male             1   37          1           6              0.0
#
#       Spending_Score  Family_Size  Segmentation
# 1                  1          3.0             0
# ...

# %% [markdown]
# ---
# **Q18**. Sauvegardez votre jeu de données dans un fichier nommé 'data_clean.csv'

# %%
df.to_csv('data_cleaned.csv', index=False)

# %%
df.Gender.apply(lambda x: x.split('a'))
# Out:
# 1       [Fem, le]
# 2       [Fem, le]
# 3         [M, le]
# 4       [Fem, le]
# 5         [M, le]
#           ...
# 7371      [M, le]
# 7372      [M, le]
# 7373    [Fem, le]
# 7374    [Fem, le]
# 7375      [M, le]
# Name: Gender, Length: 7375, dtype: object

# %% [markdown]
# # 5. Matrice de corrélation entre les variables

# %%
import pandas as pd

df = pd.read_csv('data_cleaned.csv')
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0     Female             1   38          1           3              1.0
# 1     Female             1   67          1           3              1.0
# 2       Male             1   67          1           5              0.0
# 3     Female             1   40          1           2              1.0
# 4       Male             1   56          0           0              0.0
# ...      ...           ...  ...        ...         ...              ...
# 7370    Male             1   41          1           0              0.0
# 7371    Male             0   35          0           6              3.0
# 7372  Female             0   33          1           1              1.0
# 7373  Female             0   27          1           1              1.0
# 7374    Male             1   37          1           6              0.0
#
#       Spending_Score  Family_Size  Segmentation
# 0                  1          3.0             0
# ...

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})
sns.heatmap(df.corr(), annot=True, cmap='crest')
plt.show()

# %% [markdown]
# # Importance des features

# %%
from sklearn.ensemble import RandomForestClassifier
X = df.drop(['Ever_Married'], axis = 1)
y = df.Ever_Married



model = RandomForestClassifier()
model.fit(X, y)

print("Accuracy_score du modèle : ", model.score(X, y))



feature_importances_ = model.feature_importances_
feature = pd.DataFrame({'Features': X.columns, 'Importance': feature_importances_}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature['Features'], feature['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()
# Out:
# Accuracy_score du modèle :  0.9895593220338983

# %%
# Sauvegarde du fichier notebook dans une page html
# !jupyter nbconvert --to html Exploration_data.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'Exploration_data.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...
