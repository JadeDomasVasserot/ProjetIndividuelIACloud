# %%
from sklearn.datasets import load_iris
import pandas as pd

data = load_iris()
df = pd.DataFrame(data.data, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
df['y'] = data.target

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  y
# 0             5.1          3.5           1.4          0.2  0
# 1             4.9          3.0           1.4          0.2  0
# 2             4.7          3.2           1.3          0.2  0
# 3             4.6          3.1           1.5          0.2  0
# 4             5.0          3.6           1.4          0.2  0
# ..            ...          ...           ...          ... ..
# 145           6.7          3.0           5.2          2.3  2
# 146           6.3          2.5           5.0          1.9  2
# 147           6.5          3.0           5.2          2.0  2
# 148           6.2          3.4           5.4          2.3  2
# 149           5.9          3.0           5.1          1.8  2
#
# [150 rows x 5 columns]

# %%
# Création de la table IRIS DATA
import sqlalchemy as db
import random

from utiles.functions import DataBaseV2

data = DataBaseV2(db_name='Iris_DATA', db_type='sqlite')
data.create_table('iris_data', 
                  id_columns=db.Integer, 
                  sepal_length=db.Float, 
                  sepal_width=db.Float,
                  petal_length=db.Float,
                  petal_width=db.Float)

# Injection dans la base de données
n_lines = random.randint(0, len(df)-10)

for n in range(n_lines, n_lines+10):
    data_value = df.iloc[n]
    data.insert_row('iris_data',
                    id_columns=n,
                    sepal_length = data_value.sepal_length,
                    sepal_width = data_value.sepal_width,
                    petal_length = data_value.petal_length,
                    petal_width = data_value.petal_width)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       2 import sqlalchemy as db
#       3 import random
# ----> 5 from utiles.functions import DataBaseV2
#       7 data = DataBaseV2(db_name='Iris_DATA', db_type='sqlite')
#       8 data.create_table('iris_data',
#       9                   id_columns=db.Integer,
#      10                   sepal_length=db.Float,
#      11                   sepal_width=db.Float,
#      12                   petal_length=db.Float,
#      13                   petal_width=db.Float)
#
# ModuleNotFoundError: No module named 'utiles'

# %%
data.dataframe('iris_data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'dataframe'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.dataframe('iris_data')
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_bunch.py:59, in Bunch.__getattr__(self, key)
#      57     return self[key]
#      58 except KeyError:
# ---> 59     raise AttributeError(key)
#
# AttributeError: dataframe

# %%
from plugins.utiles.functions import *

df = DataBaseV2(db_name='airflow', db_type='sqlite').dataframe("iris_data")
df
# Out:
#      id_columns  sepal_length  sepal_width  petal_length  petal_width  y
# 0             0           5.1          3.5           1.4          0.2  0
# 1             1           4.9          3.0           1.4          0.2  0
# 2             2           4.7          3.2           1.3          0.2  0
# 3             3           4.6          3.1           1.5          0.2  0
# 4             4           5.0          3.6           1.4          0.2  0
# ..          ...           ...          ...           ...          ... ..
# 145         145           6.7          3.0           5.2          2.3  2
# 146         146           6.3          2.5           5.0          1.9  2
# 147         147           6.5          3.0           5.2          2.0  2
# 148         148           6.2          3.4           5.4          2.3  2
# 149         149           5.9          3.0           5.1          1.8  2
#
# [150 rows x 6 columns]

# %%
df.y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: y, Length: 150, dtype: int64

# %%
df['y']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: y, Length: 150, dtype: int64

# %%
import os
os.environ['AWS_ACCESS_KEY_ID'] = "AKIA3R62MVALLDMAF37Q"
os.environ['AWS_SECRET_ACCESS_KEY'] = "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"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 os.environ['AWS_ACCESS_KEY_ID'] = os.getenv('AWS_ACCESS_KEY_ID')
#       3 os.environ['AWS_SECRET_ACCESS_KEY'] = os.getenv('AWS_SECRET_ACCESS_KEY')
#
# File <frozen os>:719, in __setitem__(self, key, value)
#
# File <frozen os>:793, in encode(value)
#
# TypeError: str expected, not NoneType
